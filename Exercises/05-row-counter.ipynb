# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("file_path_value", "", "File Path")

file_path = dbutils.widgets.get("file_path_value")

print(f"Input file path: {file_path}")

#file_path = "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv"

# %%
df = (spark.read.option("header", "true")
      .option("inferSchema", "true")
      .csv(file_path))

row_count = df.count()
print(f"Row count: {row_count}")
dbutils.notebook.exit(row_count)
