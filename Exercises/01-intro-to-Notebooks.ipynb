# %%
print("Hello World")

# %%
csv_path = "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv"
diamonds_df = spark.read.format("csv").option("header", "true").option('inferSchema', 'true').load(csv_path)


results_df = (diamonds_df.select('cut', 'color', 'clarity', 'price', 'carat')
.filter((diamonds_df['cut']== 'Premium') & (diamonds_df['price'] > 5000)))

display(results_df)
