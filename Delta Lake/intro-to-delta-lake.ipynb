# %%
# %sql
use catalog workspace;
use schema default;

# %%
# %sql
CREATE OR REPLACE TABLE orders(
    order_id INT,
    customer STRING,
    amount DOUBLE,
    status STRING
) using DELTA

# %%
# %sql
INSERT into orders VALUES(
    1, 'customer1', 100, 'completed'
),
(
    2, 'customer2', 200, 'completed'
),
(
    3, 'customer3', 300, 'completed'
)

# %%
# %sql
insert into orders values(
    4, 'David', 55.75, 'pending'
);

# %%
# %sql
describe history orders
