# %%
from pyspark.sql import Row
from pyspark.sql.functions import lit
from datetime import datetime, date

df = spark.createDataFrame([
    Row(id=1, name='Jonas', birthday=date(1991, 1, 1), favorite_color='blue'),
    Row(id=2, name='Kalle', birthday=date(1992, 2, 2), favorite_color='green'),
    Row(id=3, name='Kim', birthday=date(1993, 3, 3), favorite_color='red'),
    Row(id=4, name='Kalle', birthday=date(1994, 4, 4), favorite_color='green')
        ])

x = 20
y = 30
z = 40
